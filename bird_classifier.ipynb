# %%
import fastbook
fastbook.setup_book()

# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
# !pip install bing-image-downloader
from bing_image_downloader import downloader
for q in ['Common Pochard', 'Cotton Pygmy Geese', 'Greylag Geese']:
    downloader.download(q, limit=30, output_dir='birds', adult_filter_off=True, force_replace=False, timeout=5)
# Out:
# Requirement already satisfied: bing-image-downloader in /opt/conda/envs/fastai/lib/python3.8/site-packages (1.1.1)
# [%] Downloading Images to /notebooks/clean/birds/Common Pochard
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://cdn.download.ams.birds.cornell.edu/api/v1/asset/241987301/1800
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://static.thainationalparks.com/img/species/2020/08/17/395808/common-pochard-w-900.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.birdforum.net/gallery/common-pochard.640776/full
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/736x/c6/db/6b/c6db6bebbd431d5edf3db77541876ebe--photographs-photos.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.ejphoto.com/images_NC/NC_CommonPochard03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://1.bp.blogspot.com/-1goDwzHsldQ/UKfLwA92JII/AAAAAAAAGPI/WyxQdxPYAsw/s1600/IMG_4850.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://ejphoto.com/images_NC/NC_CommonPochard05.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://www.worldbirds.co.uk/images/oakes0/photos/image1893.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://www.tobiashjorth.com/wp-content/uploads/common-pochard-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://www.tringa.org/images/0408_Common_Pochard_01-28-2016_2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://cdn.birdseye.photo/media/resized/large/000285-109-20150225173048.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from http://c1.staticflickr.com/6/5550/9817024814_35df83c238.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://www.birdforum.net/gallery/common-pochard.652353/full
# [%] File Downloaded !
#
# [%] Downloading Image #14 from http://kiwifoto.com/images/galleryphotos/common_pochard/common_pochard_B13K1462.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://focusingonwildlife.com/news/wp-content/uploads/common-pochard.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://euclid.nmu.edu/~jophilli/common-pochard1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://a4.pbase.com/g9/86/959086/2/159608826.IdrXe5P5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from http://faynanheritage.org/wp-content/uploads/2020/06/71-Common-Pochard-by-Kathy-Sam-via-Flickr-CC-BY-2-0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://cdn.birdseye.photo/media/resized/medium_cropped/000285-100-20130419092003.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://cdn.britannica.com/22/116422-050-38A75FBD/European-pochard.jpg
# [Error]Invalid image, not saving https://cdn.britannica.com/22/116422-050-38A75FBD/European-pochard.jpg
#
# [!] Issue getting: https://cdn.britannica.com/22/116422-050-38A75FBD/European-pochard.jpg
# [!] Error:: Invalid image, not saving https://cdn.britannica.com/22/116422-050-38A75FBD/European-pochard.jpg
#
# [%] Downloading Image #20 from https://4.bp.blogspot.com/-Uv8XT4tZEHU/UKfcIDqd3OI/AAAAAAAAGPc/Lo6XruK7PjU/s1600/IMG_3307.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://ejphoto.com/images_NC/NC_CommonPochard14.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://www.birdguides-cdn.com/cdn/gallery/birds/Pochard-1.jpg?&amp;height=1080
# [%] File Downloaded !
#
# [%] Downloading Image #23 from http://www.birdinginmalta.com/species/pochard1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://www.ejphoto.com/images_NC/NC_CommonPochard11.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://live.staticflickr.com/7802/46034727615_41277352f9_z.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://2.bp.blogspot.com/-Xaa8s6-y9e8/TXhox1EkBRI/AAAAAAAAV8w/ttPto-LDEms/s1600/Common-Pochard-male_1269.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://birdsofgilgit.com/birds/images/Common Pochard.jpg
# [!] Issue getting: https://birdsofgilgit.com/birds/images/Common Pochard.jpg
# [!] Error:: URL can't contain control characters. '/birds/images/Common Pochard.jpg' (found at least ' ')
# [%] Downloading Image #27 from https://media.istockphoto.com/photos/common-pochard-picture-id672486726
# [%] File Downloaded !
#
# [%] Downloading Image #28 from http://www.atozpictures.com/uploads/2017/02/common-pochard-pair-pictures.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #29 from https://cdn.download.ams.birds.cornell.edu/api/v1/asset/241987301/1800
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://static.thainationalparks.com/img/species/2020/08/17/395808/common-pochard-w-900.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.
# ===============================================
#
# Please show your support here
# https://www.buymeacoffee.com/gurugaurav
#
# ===============================================
#
# [%] Downloading Images to /notebooks/clean/birds/Cotton Pygmy Geese
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.bushpea.com/bd/ph/vik/im/cotton pygmy-goose 03.jpg
# [!] Issue getting: http://www.bushpea.com/bd/ph/vik/im/cotton pygmy-goose 03.jpg
# [!] Error:: URL can't contain control characters. '/bd/ph/vik/im/cotton pygmy-goose 03.jpg' (found at least ' ')
# [%] Downloading Image #1 from https://www.aladdin.st/bird-watching/thailand/1721.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.bushpea.com/bd/ph/vik/im/cotton pygmy-goose 01.jpg
# [!] Issue getting: http://www.bushpea.com/bd/ph/vik/im/cotton pygmy-goose 01.jpg
# [!] Error:: URL can't contain control characters. '/bd/ph/vik/im/cotton pygmy-goose 01.jpg' (found at least ' ')
# [%] Downloading Image #2 from https://i.ytimg.com/vi/rxhQ_pt_NSs/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.birdsinbackyards.net/sites/www.birdsinbackyards.net/files/styles/extra-large/public/forum/pacman/images/_E3K1393ae.JPG?itok=Yy1mWewu
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://c2.staticflickr.com/8/7413/11834383763_70c308cb00_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cdn.download.ams.birds.cornell.edu/api/v1/asset/122128641/1800
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.ytimg.com/vi/y6d8YzVTJpE/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://www.aladdin.st/bird-watching/thailand/1722.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://www.nejohnston.org/Birds/2014/11/Images/IMG_9755.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://i.pinimg.com/originals/4e/ac/e8/4eace8574a8d0396f272049157905513.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://1.bp.blogspot.com/-I17k2RXQieM/TtHOLt_Rh2I/AAAAAAAAAT0/Mu6qG7Zcxds/s1600/P1070742.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://live.staticflickr.com/5645/30576256116_1002686fd8_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image
eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..fZtwPQsR79dq3wJ9gxbnN1p8OdwRm_jFuDO7_wqAD_Q
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://thumbs.dreamstime.com/b/greylag-geese-13925087.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from http://2.bp.blogspot.com/-ZgjlXXD19q0/Tiw_8kQRt7I/AAAAAAAALZE/K1ozEdi8dlI/s1600/1c+Greylag+Geese.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://amazon.clikpic.com/davidschenck/images/800_Greylags_77A0512.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://1.bp.blogspot.com/-zmrO243gS5g/TzrCWP1U0UI/AAAAAAAAHH0/HWQIc7wdH4E/s1600/1%2Bgeese.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://i.ytimg.com/vi/dbknPUGskWA/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://www.wildernesscottages.co.uk/blog/wp-content/uploads/2016/05/greylag-goose-300x182.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://www.peterkesby.co.uk/wp-content/uploads/2020/09/AS225-greylag-geese-in-flight-web.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://www.permuted.org.uk/photography/wp-content/uploads/2010/10/greylag_geese_2510106262.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from http://2.bp.blogspot.com/-4CYxx2I7ybQ/TZA20t8G01I/AAAAAAAAFRQ/UL0mSctidqg/s640/greylag+geese.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://www.jnb-birds.com/Iceland/GreylagGeese_A.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://live.staticflickr.com/3777/11999370243_9e94306330_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from http://gallery.nen.gov.uk/assets/1205/0000/0243/img_6634.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://live.staticflickr.com/65535/50044625758_1792d497ff.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #30 from https://cdn.birdwatchingdaily.com/2016/07/Greylag-Geese-Kensington-Gardens.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.
# ===============================================
#
# Please show your support here
# https://www.buymeacoffee.com/gurugaurav
#
# ===============================================

# %%
#hide
ims = ['https://www.birdforum.net/gallery/common-pochard.640776/full']

# %%
dest = 'images/Common Pochard.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85 at 0x7EFB908F7A90>

# %%
bird_types = 'Common Pochard','Cotton Pygmy Geese','Greylag Geese'
path = Path('birds')

# %%
if not path.exists():
    path.mkdir()
    for o in bird_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bird')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#90) [Path('birds/Greylag Geese/Image_30.jpg'),Path('birds/Greylag Geese/Image_29.jpg'),Path('birds/Greylag Geese/Image_2.jpg'),Path('birds/Greylag Geese/Image_5.jpg'),Path('birds/Greylag Geese/Image_18.JPG'),Path('birds/Greylag Geese/Image_28.jpg'),Path('birds/Greylag Geese/Image_15.JPG'),Path('birds/Greylag Geese/Image_7.jpg'),Path('birds/Greylag Geese/Image_8.jpg'),Path('birds/Greylag Geese/Image_22.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %%
birds = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = birds.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
birds = birds.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = birds.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
birds = birds.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = birds.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
birds = birds.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = birds.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
birds = birds.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = birds.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
birds = birds.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = birds.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.969267</td>
#       <td>1.837452</td>
#       <td>0.500000</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.941125</td>
#       <td>1.437490</td>
#       <td>0.388889</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.795431</td>
#       <td>0.597347</td>
#       <td>0.277778</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.459008</td>
#       <td>0.394141</td>
#       <td>0.166667</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.163370</td>
#       <td>0.391823</td>
#       <td>0.111111</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('Common Pochard', 'Cotton Pygmy Geese', 'Greylag Geese'), value='Common Pocha…

# %%
#hide
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/Common Pochard.jpg')
# Out:
# ('Common Pochard',
#  TensorImage(0),
#  TensorImage([9.9989e-01, 5.1649e-05, 5.8133e-05]))

# %%
learn_inf.dls.vocab
# Out:
# ['Common Pochard', 'Cotton Pygmy Geese', 'Greylag Geese']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/Common Pochard.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: Common Pochard; Probability: 0.9999')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bird!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bird!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.4.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 27.8 MB/s eta 0:00:01
# Collecting jupyterlab-server<3,>=2.3.0
#   Downloading jupyterlab_server-2.22.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 11.0 MB/s eta 0:00:01
# Collecting nbconvert<8,>=6.4.5
#   Downloading nbconvert-7.2.10-py3-none-any.whl (275 kB)
#      |████████████████████████████████| 275 kB 74.1 MB/s eta 0:00:01
# Collecting jupyter-core>=4.11.0
#   Downloading jupyter_core-5.3.0-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.6 MB/s  eta 0:00:01
# Collecting websockets>=9.0
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 53.3 MB/s eta 0:00:01
# Requirement already satisfied: traitlets<6,>=5.0.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (5.0.5)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (0.5.1)
# Collecting jupyter-server<2.0.0,>=1.18
#   Downloading jupyter_server-1.23.6-py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 60.3 MB/s eta 0:00:01
# Requirement already satisfied: jupyter-client<=7.4.1,>=6.1.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (6.1.7)
# Collecting importlib-metadata>=4.8.3; python_version < "3.10"
#   Downloading importlib_metadata-6.1.0-py3-none-any.whl (21 kB)
# Collecting packaging>=21.3
#   Downloading packaging-23.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 3.0 MB/s  eta 0:00:01
# Collecting jinja2>=3.0.3
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 65.3 MB/s eta 0:00:01
# Collecting babel>=2.10
#   Downloading Babel-2.12.1-py3-none-any.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 65.1 MB/s eta 0:00:01
# Collecting jsonschema>=4.17.3
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 15.1 MB/s eta 0:00:01
# Collecting requests>=2.28
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.9 MB/s  eta 0:00:01
# Collecting json5>=0.9.0
#   Downloading json5-0.9.11-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: bleach in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (3.2.1)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 51.1 MB/s eta 0:00:01
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (0.1.2)
# Requirement already satisfied: defusedxml in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (0.6.0)
# Collecting markupsafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.5-py2.py3-none-any.whl (24 kB)
# Collecting nbformat>=5.1
#   Downloading nbformat-5.8.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 11.0 MB/s eta 0:00:01
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (2.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<8,>=6.4.5->voila) (1.4.2)
# Collecting platformdirs>=2.5
#   Downloading platformdirs-3.2.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/fastai/lib/python3.8/site-packages (from traitlets<6,>=5.0.3->voila) (0.2.0)
# Requirement already satisfied: async-generator in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.8,>=0.4.0->voila) (1.10)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.8,>=0.4.0->voila) (1.4.3)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 17.9 MB/s eta 0:00:01
# Requirement already satisfied: prometheus-client in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.9.0)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (20.0.0)
# Collecting websocket-client
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 7.4 MB/s  eta 0:00:01
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.9.1)
# Requirement already satisfied: Send2Trash in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.5.0)
# Requirement already satisfied: tornado>=6.1.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (6.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=1.18->voila) (20.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from importlib-metadata>=4.8.3; python_version < "3.10"->jupyterlab-server<3,>=2.3.0->voila) (3.4.0)
# Requirement already satisfied: pytz>=2015.7; python_version < "3.9" in /opt/conda/envs/fastai/lib/python3.8/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2020.4)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (0.17.3)
# Collecting importlib-resources>=1.4.0; python_version < "3.9"
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting pkgutil-resolve-name>=1.3.10; python_version < "3.9"
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (20.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2020.11.8)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      |████████████████████████████████| 195 kB 78.9 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2.10)
# Requirement already satisfied: webencodings in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (1.15.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.3-py3-none-any.whl (23 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /opt/conda/envs/fastai/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=1.18->voila) (0.6.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (1.14.3)
# Requirement already satisfied: pycparser in /opt/conda/envs/fastai/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (2.20)
# Installing collected packages: importlib-metadata, packaging, markupsafe, jinja2, babel, importlib-resources, pkgutil-resolve-name, jsonschema, charset-normalizer, requests, sniffio, anyio, tinycss2, soupsieve, beautifulsoup4, mistune, fastjsonschema, platformdirs, jupyter-core, nbformat, nbconvert, websocket-client, jupyter-server, json5, jupyterlab-server, websockets, voila
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 2.0.0
#     Uninstalling importlib-metadata-2.0.0:
#       Successfully uninstalled importlib-metadata-2.0.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.4
#     Uninstalling packaging-20.4:
#       Successfully uninstalled packaging-20.4
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.2
#     Uninstalling Jinja2-2.11.2:
#       Successfully uninstalled Jinja2-2.11.2
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 3.2.0
#     Uninstalling jsonschema-3.2.0:
#       Successfully uninstalled jsonschema-3.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.0
#     Uninstalling requests-2.25.0:
#       Successfully uninstalled requests-2.25.0
#   Attempting uninstall: mistune
#     Found existing installation: mistune 0.8.4
#     Uninstalling mistune-0.8.4:
#       Successfully uninstalled mistune-0.8.4
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.7.0
#     Uninstalling jupyter-core-4.7.0:
#       Successfully uninstalled jupyter-core-4.7.0
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.0.8
#     Uninstalling nbformat-5.0.8:
#       Successfully uninstalled nbformat-5.0.8
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# nbformat 5.8.0 requires traitlets>=5.1, but you'll have traitlets 5.0.5 which is incompatible.
# nbdev 1.1.5 requires nbconvert<6, but you'll have nbconvert 7.2.10 which is incompatible.
# jupyter-core 5.3.0 requires traitlets>=5.3, but you'll have traitlets 5.0.5 which is incompatible.
# jupyter-server 1.23.6 requires jupyter-client>=6.1.12, but you'll have jupyter-client 6.1.7 which is incompatible.
# jupyter-server 1.23.6 requires traitlets>=5.1, but you'll have traitlets 5.0.5 which is incompatible.
# Successfully installed anyio-3.6.2 babel-2.12.1 beautifulsoup4-4.12.0 charset-normalizer-3.1.0 fastjsonschema-2.16.3 importlib-metadata-6.1.0 importlib-resources-5.12.0 jinja2-3.1.2 json5-0.9.11 jsonschema-4.17.3 jupyter-core-5.3.0 jupyter-server-1.23.6 jupyterlab-server-2.22.0 markupsafe-2.1.2 mistune-2.0.5 nbconvert-7.2.10 nbformat-5.8.0 packaging-23.0 pkgutil-resolve-name-1.3.10 platformdirs-3.2.0 requests-2.28.2 sniffio-1.3.0 soupsieve-2.4 tinycss2-1.2.1 voila-0.4.0 websocket-client-1.5.1 websockets-10.4
# Enabling: voila
# - Writing config: /opt/conda/envs/fastai/etc/jupyter
#     - Validating...
#       voila 0.4.0 OK

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
